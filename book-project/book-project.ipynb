# %% [markdown]
# # Text Processing Project

# %%
import string
book = "crime-punish"
wd_input = input("Enter a word! : ")

# %% [markdown]
# ### 1. Read Text File

# %%
with open (book +".txt", "r") as myfile:
    txt=myfile.read().replace('\n',' ')

# %% [markdown]
# ### 2. Clean Text

# %% [markdown]
# #### Making a new list of all words separated by a space, removing puntuation, and converting everything to lowercase

# %%
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

for ele in txt:
    if ele in punc:
        txt = txt.replace(ele, "")

#https://www.geeksforgeeks.org/python-remove-punctuation-from-string/

# %%
txt = txt.lower()
txt = txt.split(' ')
txt_list = [i for i in txt if i != '']
#txt_list

# %% [markdown]
# ### 3. Finding Next Words for Each Word

# %% [markdown]
# Make list a set to find unique words

# %%
txt_set = set(txt_list)
txt_set
# Out:
# {'pledge',
#  'lewes’',
#  'everywhere',
#  'foolishness',
#  'rightso',
#  'criminals”',
#  'far',
#  'circulating',
#  'grieved',
#  'alluring',
#  'affair”',
#  'milksop”',
#  'itbut',
#  'lady',
#  'honourable',
#  'steed',
#  'wake',
#  'leaning',
#  'thoroughfares',
#  'gasps',
#  'virtue',
#  'seconds',
#  'remarkably',
#  'papa’s',
#  'swollen',
#  '“fiancé”',
#  'blockheads',
#  'swindler',
#  'instinctively',
#  'distance',
#  '“make',
#  'histories',
#  'one’s',
#  'did',
#  'haunted',
#  'oasis',
#  'streaked',
#  'unreasoning',
#  'bloodstained',
#  'depressed”',
#  'silly’',
#  'serve',
#  'most',
#  'experienced',
#  'pouting',
#  'selfsacrifice',
#  'onceshe',
#  'halfsister',
#  'languagenot',
#  'hopes',
#  'whirl',
#  'potanchikov',
#  'impresses',
#  'praised',
#  'pashenka',
#  '“drink',
#  'taken',
#  'ejaculated',
#  'mocking',
#  'we’d',
#  'blessed',
#  'brief',
#  'excusable',
#  'created',
#  'crazy',
#  'truthwhat',
#  'jest',
#  'period',
#  'unutterable',
#  'revenge',
#  'rattle',
#  'pulled',
#  'bathed',
#  'certainly',
#  '“nervous',
#  '“guard',
#  'maniac',
#  'hemmed',
#  'cries',
#  'shrinking',
#  'listlessly',
#  'whole',
#  'libel”',
#  'seen',
#  'fit”',
#  '“love',
#  'noted',
#  'silent',
#  'invariably',
#  'years',
#  'three',
#  'pianoforte',
#  'knockdown',
#  'german',
#  '“afterwards”',
#  'learns',
#  'declaring',
#  'hatwell',
#  'ascent',
#  'napkin',
#  'miss',
#  'dirty',
#  'guard',
#  'customers',
#  'they’ve',
#  'theory',
#  'succeed',
#  'enthusiasm',
#  'chaste',
#  'mirth',
#  'beating',
#  'laundry',
#  'scowled',
#  'incorrect',
#  'moderate',
#  'pipes',
#  'spread',
#  'iron',
#  'friendly',
#  'endit',
#  'penal',
#  'hired',
#  'triumph',
#  'primeval',
#  'fainting',
#  'pedlar',
#  'journal',
#  'wandering',
#  'oneno',
#  'twitching',
#  'ferocity',
#  'interested',
#  'shake',
#  'nastasyahe',
#  'c’est',
#  'chains',
#  'svirbey',
#  'orphans',
#  'limb',
#  'squeals',
#  'language”',
#  'office”',
#  'drop',
#  'tremendous',
#  'sipped',
#  'troubles',
#  'broughtup',
#  'thunderclap',
#  'de',
#  'answer”',
#  'remoteness',
#  'prosecute',
#  'room’s',
#  'unpractised',
#  'clarionet',
#  'ruin”',
#  'stroke”',
#  'save’',
#  '“he’s',
#  'distrust',
#  'cost',
#  'goodhumouredly',
#  'alms',
#  'condescending',
#  'going',
#  'irrelevant',
#  'horizon',
#  'unnecessarily',
#  'rigout',
#  'night',
#  '“read',
#  'silently',
#  'snubnosed',
#  'forgiven',
#  'lie”',
#  'overflowed',
#  'brokenly',
#  'laws',
#  'nuisance',
#  'unrecognised',
#  'kept',
#  'lively',
#  'ark”',
#  'faint',
#  'copperred',
#  'incoherence',
#  'coxcombs',
#  'directress',
#  'throw',
#  'considered',
#  'conjecture',
#  'brilliance',
#  'signature',
#  'comforted',
#  'understood',
#  'medicinebut',
#  'abjectness',
#  'denying',
#  'heart”',
#  'never',
#  'cry',
#  'matters',
#  'exception',
#  'affably”',
#  'attentions',
#  '“i',
#  'student’s',
#  '‘behold',
#  'servile',
#  'planed',
#  'office',
#  'bottles',
#  'calls',
#  'tedious',
#  'peace”',
#  'declaration',
#  'merit”',
#  'kneel',
#  'upwards',
#  'pan”',
#  'johann',
#  'do',
#  'undoing',
#  'twentyseven',
#  'fiftyrouble',
#  'lively”',
#  'tramp',
#  'lategood',
#  'tailor’s',
#  'sad',
#  'deformed',
#  'advertising',
#  'enjoyment',
#  'strange',
#  'ashamed”she',
#  'physical',
#  'appearance’',
#  'streak',
#  'half”',
#  'die”',
#  'admonishing',
#  'advisability',
#  'poking',
#  'crimson',
#  'perlen',
#  'an',
#  'madame',
#  'turningpoint',
#  'trying',
#  'stood',
#  'dull',
#  'directly”',
#  'inquisitive',
#  'earthly',
#  'irritated',
#  '‘germans’',
#  'ancestors',
#  'lippevechsel’s',
#  'quarrelsome',
#  'remit',
#  'bureausee',
#  'nikodim',
#  'sorcery',
#  'creatureit',
#  'sworn',
#  'notei',
#  'shreds',
#  'cried”',
#  'warned',
#  'flood',
#  'attentively',
#  'used',
#  'countess',
#  'pranks',
#  'though',
#  'greediness',
#  'coffee',
#  'stooping',
#  '“economic',
#  'constantly',
#  'raspberries',
#  'suspense',
#  'footing',
#  'clamour',
#  'rash',
#  'pole',
#  'filth',
#  '“literally”',
#  'unadorned',
#  'mournfully',
#  'house’',
#  'industrious',
#  'peculiarly',
#  'granted',
#  'town',
#  'staggering',
#  'educated',
#  'effusions',
#  'bright',
#  'basin',
#  'uncle',
#  '‘again',
#  'deliberation',
#  'habitual',
#  'draggletails',
#  'unique',
#  'hiding',
#  'purify',
#  'idiot”',
#  'thickest',
#  'dressingtable',
#  'caressing',
#  'loathsome',
#  'betrays',
#  'station',
#  'cabdrivers',
#  'actors',
#  'kindly',
#  'care',
#  'clue”',
#  'gratify',
#  'consolatory',
#  'policy',
#  '“twenty',
#  'cheapest',
#  '‘what',
#  'desert',
#  'quenching',
#  'summoned',
#  'hung',
#  'feared',
#  'hahaha',
#  'cleaning',
#  'sight',
#  'diamanten',
#  'frail',
#  'sew',
#  'interposed',
#  'culture',
#  'candid',
#  'umsonst',
#  'nobler',
#  'commercial',
#  'pavlovna’s',
#  'hypochondria',
#  'starving”',
#  'puts',
#  'mother’s',
#  'inviting',
#  'aims',
#  'moment',
#  'storythe',
#  'pity',
#  'surface',
#  'suchandsuch',
#  'swaying',
#  'removing',
#  'service’”',
#  'message',
#  'haughtily',
#  'brutish',
#  'surrender',
#  'cap”',
#  'modesty',
#  'sheets',
#  'welleducated',
#  'bn',
#  'abjure',
#  'muttonchop',
#  'seats',
#  'blushing',
#  'tramps',
#  'parapet',
#  'pace',
#  'hear”',
#  'set',
#  'again“but',
#  'i’ll',
#  'compassionately“let',
#  'patterns',
#  'lamb’s',
#  'folded',
#  'filled',
#  '“hang',
#  'can’t',
#  'daughter’s',
#  'designsand',
#  'rush',
#  'oracle',
#  'fanaticism',
#  'originated',
#  'punishmentas',
#  'cartload”',
#  'groups',
#  'vigilant',
#  'educatedbusiness',
#  'john',
#  'stammering',
#  'peeling',
#  'death',
#  'respectfully',
#  'r',
#  '‘nothing',
#  'conflagrations',
#  'drove',
#  'paper”',
#  'injured',
#  'balalaïka',
#  'shivers',
#  'behaves',
#  'listen',
#  'meaning',
#  'leaves',
#  'herin',
#  'sojourning',
#  'business',
#  'worthy',
#  'unfamiliar',
#  'fount',
#  'spring',
#  'vile',
#  'mars',
#  'continually',
#  'examination',
#  'worlds',
#  'gallop”',
#  '‘if',
#  'agreed',
#  'dressed”',
#  'brutes',
#  'community”',
#  'wiped',
#  'yard',
#  'wives',
#  'victims',
#  'ironically',
#  'lodgers',
#  'opinions',
#  'centres',
#  'deduced',
#  '“mr',
#  'beggary',
#  'absurd',
#  'watching',
#  'viler',
#  'aa',
#  'y',
#  'cannot”',
#  'increasing',
#  '“which',
#  'dwelling',
#  'overserious',
#  'sisterthe',
#  'choosing',
#  'overgrown',
#  'dreadfully”',
#  'pan',
#  'professorship',
#  'smartness',
#  'cloth',
#  'punch',
#  'hole',
#  'course”',
#  'bend',
#  'reverie',
#  'including',
#  'invention',
#  'restaurant”',
#  'female',
#  'way',
#  'paths',
#  'tinkling',
#  'impatient',
#  'persuaded',
#  'decision”',
#  'crockery',
#  'boiling',
#  'accidentally',
#  '‘the',
#  'criminals',
#  'close”',
#  'ivanovitch’s',
#  'falling',
#  'resslich',
#  'singer',
#  'tale‘but',
#  'capitol',
#  'gasping',
#  'gailydressed',
#  'shoesthat',
#  'yourself”',
#  'fringe',
#  'settled',
#  'legitimate',
#  'interrogated',
#  'reliable',
#  'fourthly',
#  'beneath',
#  'grown',
#  'sister',
#  'firmness',
#  'tugged',
#  'brightly',
#  'vasya',
#  'decrepit',
#  'servant',
#  '“polenka”',
#  'mistakes',
#  'van',
#  'test”',
#  'peep',
#  'hesitatingly',
#  'periodical',
#  'lobster',
#  'kozel’s',
#  'reviling',
#  'loveshe’s',
#  'spreading',
#  'in',
#  'foolish',
#  'razumihin“we',
#  'phantom”',
#  'guilt',
#  'mixing',
#  'greatly',
#  'altogetheri’m',
#  '‘poof',
#  'overwhelming',
#  'meddle',
#  'organise',
#  'outside',
#  'torment',
#  'zigzags',
#  'repeat”',
#  '‘ave',
#  'jerusalem',
#  'yesthere',
#  'plank',
#  '“serious',
#  'learned',
#  'twitched',
#  'empty',
#  'delicately',
#  'stuckup',
#  'clear',
#  'fiancée',
#  'investigators',
#  'assumes',
#  'seasons',
#  'purchase',
#  'time’answer',
#  'unspoken',
#  'giddinessnot',
#  '“gentlemen',
#  'crossing',
#  'lined',
#  'unhappy',
#  'new”',
#  'jealous',
#  'overbalancing',
#  'teeth',
#  'vilna',
#  '“be',
#  'irksome',
#  'exchanging',
#  'horror',
#  'benevolence',
#  'we’ll',
#  'alas',
#  'shouted',
#  'soandso',
#  'townspeople',
#  'blotchy',
#  'actuality',
#  'recklessness',
#  'trained',
#  'mentioning',
#  'unsteadily',
#  'hopelessly',
#  'sister“it’s',
#  'chalk',
#  'cups',
#  'interested”',
#  'cleanliness”',
#  'loving',
#  'undressed',
#  'butterfly',
#  'alexandrovna’s',
#  'might',
#  'slander”',
#  'comforts',
#  'talent',
#  'gospel”',
#  'oddly',
#  'ivory',
#  'stumbled',
#  'hurriedly',
#  'ransack',
#  'serves',
#  'when’s',
#  'lebeziatnikov',
#  'practicality”',
#  'requiem',
#  'mihailovitch',
#  'ruining',
#  '“deuce',
#  'cleverer',
#  'jokes',
#  '“thrice',
#  'branded',
#  'impression',
#  'dandling',
#  'meditation',
#  'tobacco',
#  'terriblelooking',
#  'independent',
#  'fairhaired',
#  'grasped',
#  'knitting',
#  'rid',
#  'posed',
#  'redeemer',
#  'coincidence',
#  'ointment',
#  'rehearse',
#  'civilly',
#  'block',
#  'hurry”',
#  'helped',
#  'conveyed',
#  'associations',
#  'godless',
#  'trial',
#  'disapproval',
#  'reputation',
#  'begged',
#  'forasmuch',
#  'bitter',
#  'frowning',
#  'mewho',
#  'bareheaded',
#  '‘extraordinary’',
#  'irresistible',
#  'roaring',
#  'independence',
#  'myself”',
#  'frowned',
#  'feeding',
#  'crimes',
#  'comic',
#  '‘be',
#  'mended',
#  'disgusted',
#  'selfreliantthe',
#  'important',
#  'deserve',
#  'thanks',
#  'hand”',
#  'knock',
#  'untouched',
#  'twitch',
#  'practicality',
#  'whip',
#  'kolya',
#  'outlet',
#  'oneeyed',
#  'tribulation',
#  'beseeching',
#  'grades',
#  'wilt',
#  'reviendra”',
#  'dearlyand',
#  'surname”',
#  'falteringly',
#  'followed”',
#  'intend',
#  'young”',
#  'unfolded',
#  'passport',
#  'it”and',
#  'despair“and',
#  'officers',
#  'joke',
#  'offices',
#  'juries',
#  'fidgeting',
#  '“go',
#  'crime',
#  'suffering”',
#  'contemptible',
#  'pulse',
#  'blew',
#  '‘it’s',
#  'affecting',
#  'veal”',
#  'predestined',
#  'absurdly',
#  'hurting',
#  'perpetuity',
#  'poets',
#  'person’s',
#  'particularbeen',
#  'pecuniary',
#  'fulltwentythree',
#  'term',
#  '“too',
#  'tubercles”',
#  'amused',
#  'exaggerated”',
#  'usmarfa',
#  'spitting',
#  'convinced',
#  'acrosswhips',
#  'came”',
#  'press',
#  'angel',
#  'intention',
#  'crawling',
#  'make',
#  'speeches',
#  'hehe”',
#  'microbes',
#  'patience“come',
#  'donewhat',
#  'fellow’',
#  'dregs',
#  'acquitted',
#  'stud',
#  'inquirehave',
#  'curiosity”',
#  'voluptuous',
#  'aching',
#  'close',
#  'personages',
#  'win',
#  'hereupon”',
#  'fires',
#  '‘new',
#  'retract',
#  'lida”',
#  'ruffled',
#  'mud',
#  'slavishly',
#  'fumes',
#  'significant',
#  'kitchens',
#  'workmen’s',
#  '‘insulted',
#  '‘for',
#  'gratitude',
#  'unceremonious',
#  'irrational',
#  'fences',
#  'turkish',
#  'good',
#  'builds',
#  '“serves',
#  'offensive',
#  'defiance',
#  'nonchalant',
#  'arrogant',
#  'liethat',
#  'conceited',
#  'inscribed',
#  'if',
#  '“goodbye',
#  'due',
#  'lift',
#  'disturb',
#  'tablecloth',
#  'conduct',
#  'window”',
#  'hush',
#  'mainland',
#  'conveniently',
#  'elsei',
#  'snoring',
#  'stepmother',
#  'tracks',
#  'the',
#  'corruption',
#  'furious',
#  'expedition',
#  'missy',
#  'else',
#  'wheels',
#  'condescended',
#  'generosity',
#  'behavior',
#  'venturing',
#  'witticism',
#  'extreme',
#  'regularity',
#  'sat“she',
#  'ninety',
#  '‘could',
#  'transformed',
#  'existed',
#  'type',
#  'noticed',
#  'ikon',
#  'extenuating',
#  '“father',
#  'curtsied',
#  'dost',
#  'crucify',
#  'prepossessing',
#  'unredeemed',
#  'believest',
#  'sceptical',
#  'paint”',
#  'taught',
#  'admission',
#  'spluttering',
#  'extremity',
#  'locality',
#  'means',
#  'vise',
#  'obtuse',
#  'love’',
#  'lockup',
#  'shouts',
#  'prudence',
#  '“you’re',
#  'gaining',
#  'ins',
#  'trusts',
#  'portrait',
#  'hospitality',
#  'redeemedbracelets',
#  'attention”',
#  '“afterwards',
#  'striving',
#  'rustle',
#  'reveal',
#  'obscure',
#  'brigands',
#  'murderer”',
#  'outsider',
#  'draught',
#  'vulgarity',
#  'psychology',
#  'cardsharper”',
#  'impulse',
#  'witnessand',
#  'casuists',
#  'singing',
#  'compressed',
#  'aglow',
#  'idea”',
#  '“at',
#  '‘run',
#  'signing”',
#  'join',
#  'jargon',
#  'rapidity',
#  'peevish',
#  'said',
#  'zaraïsky',
#  'searchthere',
#  'apprehension',
#  'dmitri”',
#  'brought”',
#  'friend’s',
#  'cart”',
#  'implied',
#  'funny”',
#  'poems',
#  'tables',
#  'recurring',
#  'paris',
#  'anythingpolenka',
#  '“missing',
#  'several',
#  'provisions',
#  'falsetto',
#  'en',
#  'drinking’',
#  'weekhe',
#  'liquor',
#  'club',
#  'fate”',
#  'wooden',
#  'lover',
#  '“she’ll',
#  'harden',
#  'copper',
#  'poppet',
#  'obvious',
#  '“bravo',
#  'acquired',
#  'barriers',
#  'noah’s',
#  'suddenlyput',
#  'inside',
#  'names',
#  '“',
#  'hefondly',
#  'humanityto',
#  'rôles',
#  'fro',
#  'dullest',
#  'goodwill',
#  'man”“that',
#  'noticed’what',
#  'vigorously',
#  'ivanovnatime',
#  'catching',
#  'frightened”',
#  'say”',
#  'changed',
#  'played',
#  'fainted',
#  'brotherach',
#  'poof”',
#  'sinless',
#  'semyon',
#  'rude',
#  'breathe',
#  'retired',
#  'developing',
#  'performed',
#  'experience',
#  'treasure',
#  '“that',
#  'lived”',
#  'insanity”',
#  'hag',
#  'anticipated',
#  'persistent',
#  'knot',
#  'coherent',
#  'shivered',
#  'letting',
#  'succour”',
#  'heheheyour',
#  'injurious',
#  'administrative',
#  'sweetheart',
#  'ears',
#  'initial”',
#  'intonation',
#  'cloud',
#  'gone”',
#  'commits',
#  'perceptions',
#  'stone”',
#  'din',
#  'yesterday',
#  'fast',
#  'germans',
#  'law”',
#  'violent',
#  'fedosya',
#  'thirtytwo',
#  'mohair',
#  '‘take',
#  '“listen”',
#  'nursing',
#  'clicking',
#  'raspberry',
#  'insufferable',
#  'unlatched',
#  'terrified',
#  'threat',
#  'nothing',
#  'tomb”',
#  'basements',
#  'spectators',
#  'captured',
#  'covering',
#  'good”',
#  'resounded',
#  'tubercles',
#  'that',
#  'bricks',
#  'knocking',
#  'brimless',
#  'kissing',
#  'peaceful',
#  'crowd',
#  'honoured',
#  'untied',
#  'minute”',
#  'timeonly',
#  'apparently',
#  'himand',
#  'blurt',
#  'unbelieving',
#  'pretensions',
#  'favourite',
#  'earrings”',
#  'unlocking',
#  'entered',
#  'lieutenant’',
#  '“show',
#  'additions',
#  'same',
#  'already',
#  'arrangement',
#  ...}

# %% [markdown]
# Removing words that are not from the actual story

# %%
# txt_set = txt_set.remove('CHAPTER')
# type(txt_set)

# %% [markdown]
# Making the set of unique words a dictionary

# %%
txt_dict = dict.fromkeys(txt_set, '') #https://www.geeksforgeeks.org/python-convert-a-set-into-dictionary/
#txt_dict

# %% [markdown]
# Making lists of all the following words and adding them to the dictionary

# %%
def get_next_words(word):
    next_words =[]
    for i in range(len(txt_list)-1):
       if txt_list[i] == word:
          next_words.append(txt_list[i+1])
    return next_words

# %%
for word in txt_set:
    txt_dict[word] = get_next_words(word)

# %%
#txt_dict

# %% [markdown]
# ### 4. Find the most common next word for each unique word

# %%
def most_frequent_word(list):
    return max(set(list), key=list.count)

#https://stackoverflow.com/questions/1518522/find-the-most-common-element-in-a-list

# %% [markdown]
# ### 5. Make a final dictionary with every word the most frequent following word

# %%
final_dict = dict.fromkeys(txt_set,'')

for word in txt_set:
    final_dict[word] = most_frequent_word(get_next_words(word))

#final_dict

# %% [markdown]
# ### 6. Create a sentence using inputted word

# %%
if wd_input in txt_set:
    print(final_dict[wd_input])
