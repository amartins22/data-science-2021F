# %% [markdown]
# # Chess Analysis

# %%
import os
import json
import pandas as pd

# %%
game_dir = f'./game-data-marty400/'

for filename in os.listdir(game_dir):
    print('-'*40)
    with open(game_dir + filename) as f:
        games_dict = json.load(f)
    print(games_dict)
# Out:
# ----------------------------------------
# ...
