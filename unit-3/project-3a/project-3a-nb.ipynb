# %% [markdown]
# # Project 3A

# %% [markdown]
# ### Boston Crime Data

# %% [markdown]
# Setup:

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Create and print DataFrame:

# %%
bos_crime_data = pd.read_csv("crime.csv", index_col = 0)
pd.set_option('display.max_rows', 3000)
pd.set_option('display.min_rows', None)
bos_crime_data
# Out:
#                  OFFENSE_CODE                OFFENSE_CODE_GROUP  \
# INCIDENT_NUMBER
# I182070945                619                           Larceny
# I182070943               1402                         Vandalism
# I182070941               3410                             Towed
# I182070940               3114              Investigate Property
# I182070938               3114              Investigate Property
# I182070936               3820   Motor Vehicle Accident Response
# I182070933                724                        Auto Theft
# I182070932               3301                   Verbal Disputes
# I182070931                301                           Robbery
# I182070929               3301                   Verbal Disputes
# I182070928               3301                   Verbal Disputes
# I182070927               3114              Investigate Property
# I182070923               3108              Fire Related Reports
# ...

# %% [markdown]
# Replace shooting results with Booleans:

# %%
bos_crime_data['SHOOTING'] = bos_crime_data['SHOOTING'].replace(['Y'],'1')
bos_crime_data['SHOOTING'] = bos_crime_data['SHOOTING'].replace(['NaN'],'0')

# %%
bos_crime_data
# Out:
#                  OFFENSE_CODE                OFFENSE_CODE_GROUP  \
# INCIDENT_NUMBER
# I182070945                619                           Larceny
# I182070943               1402                         Vandalism
# I182070941               3410                             Towed
# I182070940               3114              Investigate Property
# I182070938               3114              Investigate Property
# I182070936               3820   Motor Vehicle Accident Response
# I182070933                724                        Auto Theft
# I182070932               3301                   Verbal Disputes
# I182070931                301                           Robbery
# I182070929               3301                   Verbal Disputes
# I182070928               3301                   Verbal Disputes
# I182070927               3114              Investigate Property
# I182070923               3108              Fire Related Reports
# ...
